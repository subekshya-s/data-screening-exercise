# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## Import Required Libraries
#
# We import the main library used for data cleaning:
#
# - **pandas (pd)** → Used for reading, writing, and cleaning tabular data like CSV files.
#
# This library is essential for any data analysis or data cleaning task in Python.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  ## Read the csv file for the cleaning and store it as a table name df

# %%
df =  pd.read_csv('data/messy_ice_detention.csv')

# %% [markdown]
# ## Display the first few rows and colum to detect :
#  - how messy the data is
#  - whether headers are correct if there is any extra title rows or notes

# %%
df.head(9)
# Out:
#                                                      Unnamed: 1 Unnamed: 2  \
# 0  These statistics are made available to the pub...        NaN        NaN
# 1                          ICE FACILITIES DATA, FY25        NaN        NaN
# 2  ICE Enforcement and Removal Operations Data, F...        NaN        NaN
# 3  This list is limited to facilities that have a...        NaN        NaN
# 4  Data Source: ICE Integrated Decision Support (...        NaN        NaN
# 5                                               Name       City      State
# 6                            ADAMS COUNTY DET CENTER    NATCHEZ         MS
# 7                     ADELANTO ICE PROCESSING CENTER   ADELANTO         CA
# 8                 ALAMANCE COUNTY DETENTION FACILITY     GRAHAM         NC
#
#     Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
# 5      Level A      Level B      Level C      Level D
# 6  1876.461078  266.4311377  6.724550898   4.25748503
# 7  6.401197605  4.323353293  22.60479042  32.63473054
# 8  4.329341317  3.461077844  6.083832335  6.185628743
#
#                  Unnamed: 7
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5  Last Inspection End Date
# 6                     45673
# 7                     45491
# 8                     45554

# %% [markdown]
# ## Remove unnecessary top rows
# This command removes the first 5 rows so that only real data remains.

# %%
df = df.iloc[5:]

# %% [markdown]
# ##  Verify Data After Row Removal
#
# preview the dataset again to confirm that:
#
# - The correct data now starts at the top
# - Columns look more structured

# %%
df.head(6)
# Out:
#                                         Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 5                                 Name        City      State      Level A
# 6              ADAMS COUNTY DET CENTER     NATCHEZ         MS  1876.461078
# 7       ADELANTO ICE PROCESSING CENTER    ADELANTO         CA  6.401197605
# 8   ALAMANCE COUNTY DETENTION FACILITY      GRAHAM         NC  4.329341317
# 9         ALEXA$NDRIA STAGING FACILITY  ALEXANDRIA         LA  137.5209581
# 10                ALLEGANY COUNTY JAIL     BELMONT         NY  1.221556886
#
#      Unnamed: 4   Unnamed: 5   Unnamed: 6                Unnamed: 7
# 5       Level B      Level C      Level D  Last Inspection End Date
# 6   266.4311377  6.724550898   4.25748503                     45673
# 7   4.323353293  22.60479042  32.63473054                     45491
# 8   3.461077844  6.083832335  6.185628743                     45554
# 9   47.41317365  76.00598802  52.48502994                     45533
# 10     1.80E-02            0            0                       NaN

# %% [markdown]
# ## Save cleaned part into new csv not to loose the original data incase if needed

# %%
df.to_csv("data/partially_cleaned_ice_detention.csv",index=False,encoding="utf-8")

# %%
df.head()
# Out:
#                                        Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 5                                Name        City      State      Level A
# 6             ADAMS COUNTY DET CENTER     NATCHEZ         MS  1876.461078
# 7      ADELANTO ICE PROCESSING CENTER    ADELANTO         CA  6.401197605
# 8  ALAMANCE COUNTY DETENTION FACILITY      GRAHAM         NC  4.329341317
# 9        ALEXA$NDRIA STAGING FACILITY  ALEXANDRIA         LA  137.5209581
#
#     Unnamed: 4   Unnamed: 5   Unnamed: 6                Unnamed: 7
# 5      Level B      Level C      Level D  Last Inspection End Date
# 6  266.4311377  6.724550898   4.25748503                     45673
# 7  4.323353293  22.60479042  32.63473054                     45491
# 8  3.461077844  6.083832335  6.185628743                     45554
# 9  47.41317365  76.00598802  52.48502994                     45533

# %% [markdown]
# ## Reloading the csv with the proper header and column names

# %%
df = pd.read_csv("data/partially_cleaned_ice_detention.csv",skiprows=1,header=0)

# %%
df.head(5)
# Out:
#                                  Name        City State      Level A  \
# 0             ADAMS COUNTY DET CENTER     NATCHEZ    MS  1876.461078
# 1      ADELANTO ICE PROCESSING CENTER    ADELANTO    CA     6.401198
# 2  ALAMANCE COUNTY DETENTION FACILITY      GRAHAM    NC     4.329341
# 3        ALEXA$NDRIA STAGING FACILITY  ALEXANDRIA    LA   137.520958
# 4                ALLEGANY COUNTY JAIL     BELMONT    NY     1.221557
#
#       Level B    Level C    Level D Last Inspection End Date
# 0  266.431138   6.724551   4.257485                    45673
# 1    4.323353  22.604790  32.634731                    45491
# 2    3.461078   6.083832   6.185629                    45554
# 3   47.413174  76.005988  52.485030                    45533
# 4    0.018000   0.000000   0.000000                      NaN

# %% [markdown]
# ##  Inspect Dataset Structure and Data Types
#
# This step displays information about the dataset, including:
#
# - Column names
# - Data types of each column (text, numbers, etc.)
# - Number of non-null (non-missing) values in each column
# - Total number of rows in the dataset
#
# This helps identify:
# - Which columns need type conversion (e.g., object → datetime)
# - Which columns contain missing values
# - Whether the dataset is suitable for analysis or needs more cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      134 non-null    object
#  1   City                      134 non-null    object
#  2   State                     134 non-null    object
#  3   Level A                   134 non-null    float64
#  4   Level B                   134 non-null    float64
#  5   Level C                   134 non-null    float64
#  6   Level D                   134 non-null    float64
#  7   Last Inspection End Date  117 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 8.5+ KB

# %% [markdown]
# ## Check total number of missing values

# %%
df.isnull().sum()
# Out:
# Name                         0
# City                         0
# State                        0
# Level A                      0
# Level B                      0
# Level C                      0
# Level D                      0
# Last Inspection End Date    17
# dtype: int64

# %% [markdown]
# ## Inspect Facility Names
#    displayed it to :
# - detect the unwanted characters such as numbers or symbols

# %%
df['Name'].unique()
# Out:
# array(['ADAMS COUNTY DET CENTER', 'ADELANTO ICE PROCESSING CENTER',
#        'ALAMANCE COUNTY DETENTION FACILITY',
#        'ALEXA$NDRIA STAGING FACILITY', 'ALLEGANY COUNTY JAIL',
#        'ALL%EN PARISH PUBLIC SAFETY +COMPLEX', 'ATLANTA�US�PEN',
#        'B^AKER COUNTY SHERIFF DEPT.', 'BERLIN FED. CORR. INST.',
#        'BLUEBONNET DETENTION FACILITY', 'BOONE COUNTY JAIL',
#        'BROWARD COUNTY JAIL', 'BROWARD TRANSITIONAL CENTER',
#        'BUFFALO SERVICE PROCESSING CENTER', 'BUTLER COUNTY JAIL',
#        'CALHOUN C(OUNTY CORRECTIONAL CENTER',
#        'CAROLINE DETENTION FACILITY', 'CCA, FLORENCE CORRECTIONAL CENTER',
#        'CENTRAL LOUISIANA ICE PROCESSING CENTER (CLIPC)',
#        'CHASE COUNTY JAIL', 'CHIPPEWA COUNTY SSM',
#        'CIBOLA COUNTY CORRECTIONAL CENTER', 'CIMMARR.ON CORR FACILITY',
#        'CLAY COUNTY JUSTICE CENTER',
#        'CLINTON COUNTY CORRECTIONAL FACILITY', 'CLINTON COUNTY JAIL',
#        'COASTAL BEND DETENTION FACILITY',
#        'COLLIER COUNTY NAPLES JAIL CENTER', 'CUMB^ERLAND COUNTY JAIL',
#        'DAKOTA COUNTY JAIL',
#        'DALLAS COUNTY JAIL -+ LEW STERRETT JUSTICE CENTER',
#        'DENVER CONTRACT DETENTION FACILITY',
#        'DEPARTMENT OF CORRECTIONS HAGATNA', 'DE)SERT VIEW ANNEX',
#        'DODGE COUNTY JAIL', 'EAST HIDALGO DETENTION CENTER',
#        'EDEN DETENTION CTR', 'EL PASO SERVICE PROCESSING CENTER',
#        'EL PASO SOFT SIDED FACILI', 'EL VAL&LE DETENTION FACILITY',
#        'ELIZABETH CONT^RACT DETENTION FACILITY',
#        'ELOY FEDERAL CONTRACT FACILITY', 'ERIE COUNTY JAIL',
#        'ETOWAH COUNTY JAIL (ALABAMA)', 'FAYETTE COUNTY DETENTION CENTER',
#        'FDC PHILADELPHIA', 'FLORENCE SERVICE) PROCESSING CENTER',
#        'FLORENCE STAGING FACILITY', 'FOLKSTON ANNEX IPC',
#        'FOLKSTO^N MAIN IPC', 'FREEBORN COUNTY ADULT DETENTION CENTER',
#        'GEAUGA COUNTY JAIL', 'GOLDEN STATE ANNEX',
#        'GRAND FORKS COUNTY CORRECTIONAL FACILI@TY', 'GRAYSON COUNTY JAIL',
#        'GREENE COUNTY JAIL', 'HANCOCK COUNTY PUBLIC SAFETY COMPLEX',
#        'HENDERSON DETENTION', 'HONOLULU FEDERAL DETENTION CENTER',
#        'HOUSTON CONTRACT .DETENTION FACILITY',
#        'IAH SECURE ADULT DETENTION FACILITY+ (POLK)',
#        'IMPERIAL REGIONAL DETENTION FACILITY',
#        'JACKSON PARISH CORRECTIONAL CENTER', 'JEFFERSON COUNTY JAIL',
#        'JOE CORLEY PROCESSING CTR', 'KANDIYOHI COUNTY JAIL',
#        'KARNES COUNTY CORRECTIONAL) CE#NTER',
#        'KARNE_S COUNTY IMMIGRATION PROCESSING CENTER',
#        'KAY CO JUSTICE FACILITY', 'KNOX COUNTY DETENTION FACILITY',
#        'KROME NORTH SERVICE& PROCESSING CENTER',
#        'LA SALLE COUNTY REGIONAL DETENTION CENTER',
#        'LAREDO PROCESSING CENTER', 'LEAV@ENWORTH US PENITENTIARY',
#        'LEXINGTON COUNTY JAIL', 'LIMESTONE COUNTY DETENTION CENTER',
#        'LINCOLN COUNTY JAIL', 'MARION COUNTY JAIL',
#        'MESA VERDE ICE PROCESSING CENTER', 'MIAMI FEDERAL DETENTION',
#        'MIAMI STAGING FACILITY', 'MONROE COUNTY DETENTION-DORM',
#        'MONTGOMERY ICE PROCESSING CENTER',
#        'MOSHANNON& VALLEY PROCESSING CENTER',
#        'NASSAU COUNTY CORRECTIONAL CENTER',
#        'NEVADA SOUTHERN DETENTION CENTER', 'NEW HANOVER COUNTY JAIL',
#        'NORTHEAST OHIO CORRECTIONAL CENTER',
#        'NORTHWEST ICE PROCESSSING CENTER',
#        'NORTHWEST STATE CORRECTI+ONAL CENTER', 'OLDHAM COUNTY JAIL',
#        'ORANGE COUNTY JAIL (FL)', 'ORANGE COUNTY JAIL (NY)',
#        'OTAY MESA DETENTION CENTER', 'OTERO COUNTY PROCESSING CENTER',
#        'PHELPS COUNTY JAIL', 'PICKENS COUNTY DET CTR', 'PIKE COUNTY JAIL',
#        'PINE PRAIRIE ICE PROCESSING CENTER', 'PINELLAS COUNTY JAIL',
#        'PLATTE COUNTY JAIL', 'PLYMOUTH COUNTY CORRECTIONAL FACILITY',
#        'POLK COUNTY JAIL', 'PORT ISABEL SPC', 'POTTAWATTAMIE COUNTY JAIL',
#        'PRAIRIELA)ND DETENTION CENTER',
#        'PRINCE EDWARD COUNTY (FARMVILLE)', 'RICHWOOD CORRECTIONAL CENTER',
#        'RIO GRANDE DET)ENTION CENTER', 'RIVER CORRECTIONAL CENTER',
#        'ROBERT A DEYTON DETENT*ION FACILITY',
#        'SAIPAN DEPARTMENT OF CORRECTIONS (SUSUPE)',
#        'SALT LAKE COUNTY METRO JAIL', 'SAN JUAN STAGING',
#        'SAN LUIS REGIONAL DETENTION CENTER', 'SENECA COUNTY JAIL', ' ',
#        'SOUTH CENTRAL REGIONAL JAIL',
#        'SOUTH LOUISIAN%A ICE PROCESSING CENTER',
#        'SOUTH TEXAS ICE PROCESSING CENTER', 'ST. CLAIR COUNTY JAIL',
#        'STE. GENEVIEVE COUNTY SHERIFF/JAIL', 'STEWART DETENTION CENTER',
#        'SWEETWATER COUNTY JAIL', 'T DON HUTTO DETENTION CENT@ER',
#        'TORRANCE/ESTANCIA, NM',
#        'TULSA COUNTY JAIL (DAVID L. MOSS JUSTICE CTR)',
#        'TWO BRIDGES REGIONAL JAI(L', 'WASHINGTON COUNTY DETENTION CENTER',
#        'WASH(OE COUNTY JAIL', 'WEBB COUNTY DETENTION CENTER (CCA)',
#        'WINN CORRECTIONAL CENTER', 'WYATT DETENTION CENTER'], dtype=object)

# %% [markdown]
# ##  Remove Special Characters from Facility Names
#
# Facility names sometimes contain unwanted characters such as numbers or symbols.
#
# This step cleans the Name column by:
# - Removing text inside parentheses (e.g., "ADAMS COUNTY DETENCTION CENTER(ACDC)" → "ADAMS COUNTY DETENCTION CENTER")
# - Uppercase and lowercase letters (A–Z, a–z)
# - Spaces between words
#
# Cleaning text like this helps:
# - Standardize names
# - Improve matching and grouping
# - Avoid errors during analysis

# %%
df['Name'] = df['Name'].str.replace(r'\s*\(.*?\)', '', regex=True)
df['Name'] = df['Name'].str.replace(r'[^A-Za-z\s]','',regex=True)
df
# Out:
#                                    Name           City State      Level A  \
# 0               ADAMS COUNTY DET CENTER        NATCHEZ    MS  1876.461078
# 1        ADELANTO ICE PROCESSING CENTER       ADELANTO    CA     6.401198
# 2    ALAMANCE COUNTY DETENTION FACILITY         GRAHAM    NC     4.329341
# 3           ALEXANDRIA STAGING FACILITY     ALEXANDRIA    LA   137.520958
# 4                  ALLEGANY COUNTY JAIL        BELMONT    NY     1.221557
# ..                                  ...            ...   ...          ...
# 129  WASHINGTON COUNTY DETENTION CENTER   FAYETTEVILLE    AR     0.922156
# 130                  WASHOE COUNTY JAIL           RENO    NV     0.814371
# 131        WEBB COUNTY DETENTION CENTER         LAREDO    TX   234.455090
# 132            WINN CORRECTIONAL CENTER      WINNFIELD    LA  1013.023952
# 133              WYATT DETENTION CENTER  CENTRAL FALLS    RI    16.221557
#
#         Level B     Level C    Level D Last Inspection End Date
# 0    266.431138    6.724551   4.257485                    45673
# 1      4.323353   22.604790  32.634731                    45491
# 2      3.461078    6.083832   6.185629                    45554
# 3     47.413174   76.005988  52.485030                    45533
# 4      0.018000    0.000000   0.000000                      NaN
# ..          ...         ...        ...                      ...
# 129    1.119760    1.203593   0.401198                    45232
# 130    2.023952    3.443114   3.700599                    45603
# 131    4.335329   27.724551  52.934132                    45694
# 132  214.772455  187.005988  94.580838                    45673
# 133    4.077844   42.329341  49.197605                    45554
#
# [134 rows x 8 columns]

# %% [markdown]
# ## Verify the Format of the Last Inspection End Date
#
# This step helps identify the format of the dates present in the dataset.
#
# It was observed that most of the dates are stored in  Excel serial number format,
# while only one record appears in a standard readable date format.
#
# Understanding this is important because Excel date codes must be converted into
# proper datetime values before analysis or visualization.

# %%
df['Last Inspection End Date'].unique()
# Out:
# array(['45673', '45491', '45554', '45533', nan, '45638', '45589', '45617',
#        '45645', '45596', '44288', '45526', '45484', '45666', '45407',
#        '45715', '45470', '45449', '45694', '45631', '45547', '45633',
#        '45701', '45365', '45519', '45722', '45371', '44533', '45685',
#        '45687', '45421', '45729', '45394', '45372', '45723', '45561',
#        '45695', '45512', '45649', '45291', '45456', ' 9/19/2024', '45603',
#        '45505', '45373', '45704', '45246', '45359', '45562', '45414',
#        '45377', '45232'], dtype=object)

# %% [markdown]
# ## Converting Mixed Date Formats to Datetime
#
# The **Last Inspection End Date** column contains dates stored in multiple formats:
# - Excel serial date numbers (numeric values)
# - Standard string-based date formats
#
# To ensure consistency and enable reliable analysis, the column is converted to a
# single 'datetime64[ns]' format using a multi-step approach:
#
# 1. Identify rows containing numeric values, which represent Excel serial dates.
# 2. Convert Excel serial numbers to datetime using the correct origin ('1899-12-30').
# 3. Parse string-based dates while safely coercing invalid entries to 'NaT'.
# 4. Enforce a consistent datetime data type across the entire column.
# 5. Verify the final data type and preview the converted values.
#
# This approach prevents data loss and ensures all valid dates are correctly standardized.

# %%
import pandas as pd

col = 'Last Inspection End Date'

# Step 1: Identify numeric (Excel serial) rows
is_excel = df[col].apply(lambda x: str(x).replace('.', '', 1).isdigit())

# Step 2: Convert Excel serial numbers to datetime
df.loc[is_excel, col] = pd.to_datetime(
    df.loc[is_excel, col].astype(float),
    origin='1899-12-30',
    unit='D'
)

# Step 3: Convert string dates to datetime
df.loc[~is_excel, col] = pd.to_datetime(
    df.loc[~is_excel, col].astype(str).str.strip(),
    errors='coerce'
)

# Step 4: Force entire column to datetime64[ns] (coerce any leftover invalid)
df[col] = pd.to_datetime(df[col], errors='coerce')

# Step 5: Verify type
print(df[col].dtype)   # should be datetime64[ns]
print(df[col].head())
# Out:
# datetime64[ns]
# 0   2025-01-16
# 1   2024-07-18
# 2   2024-09-19
# 3   2024-08-29
# 4          NaT
# Name: Last Inspection End Date, dtype: datetime64[ns]

# %% [markdown]
# ## Checking  the data format after the operation above

# %%
df.head(50)
# Out:
#                                                Name             City State  \
# 0                           ADAMS COUNTY DET CENTER          NATCHEZ    MS
# 1                    ADELANTO ICE PROCESSING CENTER         ADELANTO    CA
# 2                ALAMANCE COUNTY DETENTION FACILITY           GRAHAM    NC
# 3                       ALEXANDRIA STAGING FACILITY       ALEXANDRIA    LA
# 4                              ALLEGANY COUNTY JAIL          BELMONT    NY
# 5                ALLEN PARISH PUBLIC SAFETY COMPLEX          OBERLIN    LA
# 6                                      ATLANTAUSPEN          ATLANTA
# 7                         BAKER COUNTY SHERIFF DEPT        MACCLENNY    FL
# 8                              BERLIN FED CORR INST           BERLIN    NH
# 9                     BLUEBONNET DETENTION FACILITY            ANSON    TX
# 10                                BOONE COUNTY JAIL       BURLINGTON    KY
# 11                              BROWARD COUNTY JAIL    FT.LAUDERDALE    FL
# 12                      BROWARD TRANSITIONAL CENTER    POMPANO BEACH    FL
# 13                BUFFALO SERVICE PROCESSING CENTER          BATAVIA    NY
# 14                               BUTLER COUNTY JAIL         HAMILTON    OH
# 15               CALHOUN COUNTY CORRECTIONAL CENTER     BATTLE CREEK    MI
# 16                      CAROLINE DETENTION FACILITY    BOWLING GREEN    VA
# 17                 CCA FLORENCE CORRECTIONAL CENTER         FLORENCE    AZ
# 18          CENTRAL LOUISIANA ICE PROCESSING CENTER             JENA    LA
# 19                                CHASE COUNTY JAIL  COTTONWOOD FALL    KS
# 20                              CHIPPEWA COUNTY SSM  SAULT STE MARIE    MI
# 21                CIBOLA COUNTY CORRECTIONAL CENTER            MILAN    NM
# 22                          CIMMARRON CORR FACILITY          CUSHING    OK
# 23                       CLAY COUNTY JUSTICE CENTER           BRAZIL    IN
# 24             CLINTON COUNTY CORRECTIONAL FACILITY       MCELHATTAN    PA
# 25                              CLINTON COUNTY JAIL      PLATTSBURGH    NY
# 26                  COASTAL BEND DETENTION FACILITY         ROBSTOWN    TX
# 27                COLLIER COUNTY NAPLES JAIL CENTER           NAPLES    FL
# 28                           CUMBERLAND COUNTY JAIL         PORTLAND    ME
# 29                               DAKOTA COUNTY JAIL      DAKOTA CITY    NE
# 30  DALLAS COUNTY JAIL  LEW STERRETT JUSTICE CENTER           DALLAS    TX
# 31               DENVER CONTRACT DETENTION FACILITY           AURORA    CO
# 32                DEPARTMENT OF CORRECTIONS HAGATNA          HAGATNA    GU
# 33                                DESERT VIEW ANNEX         ADELANTO    CA
# 34                                DODGE COUNTY JAIL           JUNEAU    WI
# 35                    EAST HIDALGO DETENTION CENTER         LA VILLA    TX
# 36                               EDEN DETENTION CTR             EDEN    TX
# 37                EL PASO SERVICE PROCESSING CENTER          EL PASO    TX
# 38                        EL PASO SOFT SIDED FACILI          EL PASO    TX
# 39                      EL VALLE DETENTION FACILITY     RAYMONDVILLE    TX
# 40            ELIZABETH CONTRACT DETENTION FACILITY        ELIZABETH    NJ
# 41                   ELOY FEDERAL CONTRACT FACILITY             ELOY    AZ
# 42                                 ERIE COUNTY JAIL             ERIE    PA
# 43                               ETOWAH COUNTY JAIL          GADSDEN    AL
# 44                  FAYETTE COUNTY DETENTION CENTER        LEXINGTON    KY
# 45                                 FDC PHILADELPHIA     PHILADELPHIA    PA
# 46               FLORENCE SERVICE PROCESSING CENTER         FLORENCE    AZ
# 47                        FLORENCE STAGING FACILITY         FLORENCE    AZ
# 48                               FOLKSTON ANNEX IPC         FOLKSTON    GA
# 49                                FOLKSTON MAIN IPC         FOLKSTON    GA
#
#         Level A     Level B     Level C     Level D Last Inspection End Date
# 0   1876.461078  266.431138    6.724551    4.257485               2025-01-16
# 1      6.401198    4.323353   22.604790   32.634731               2024-07-18
# 2      4.329341    3.461078    6.083832    6.185629               2024-09-19
# 3    137.520958   47.413174   76.005988   52.485030               2024-08-29
# 4      1.221557    0.018000    0.000000    0.000000                      NaT
# 5    101.311377   30.251497   33.766467   10.664671               2024-12-12
# 6     17.341317    3.610778    3.053892    2.724551                      NaT
# 7     26.221557   38.640719   88.652695   88.730539               2024-10-24
# 8      1.748503    0.089800    0.970060    0.712575                      NaT
# 9    311.305389  164.550898  241.616767  104.514970               2024-12-12
# 10    28.323353   22.922156   33.329341   56.431138               2024-11-21
# 11     0.335329    0.209581    1.053892    0.233533                      NaT
# 12   495.467066  158.353293    3.844311    0.718563               2024-12-19
# 13   235.688623   46.083832  133.586826  151.275449               2024-10-31
# 14     1.514970    0.598802    0.838323    0.107784               2021-04-02
# 15    56.784431   35.293413   30.982036   15.952096               2024-08-22
# 16   111.107784   33.880240   62.514970   76.922156               2024-07-11
# 17    50.449102   40.622754  145.221557  141.742515               2024-12-12
# 18   410.970060  221.209581  344.790419  207.161677               2025-01-09
# 19    19.113772   17.976048   33.772455   17.766467               2024-08-22
# 20     9.065868    4.023952    6.880240    6.125749               2024-04-25
# 21   148.167665   21.335329    0.760479    0.658683               2025-02-27
# 22    17.059880    3.670659    0.311377    0.000000                      NaT
# 23    53.401198   29.568862   91.209581   63.616766               2024-06-27
# 24     2.880240   23.718563   36.305389   16.005988               2025-01-16
# 25     2.185629    0.526946    1.754491    0.185629               2024-06-06
# 26     0.880240    2.239521    0.311377    0.113772               2025-02-06
# 27     6.089820    2.077844    2.574850    1.766467               2024-12-05
# 28     7.532934    1.137725   19.796407   16.892216               2024-09-12
# 29     2.047904    2.209581    2.401198    1.694611               2024-12-07
# 30     6.832335    0.000000    0.012000    0.005990               2024-07-18
# 31   624.568862  190.508982  189.658683  141.365270               2025-02-13
# 32     0.000000    1.461078    2.964072    0.497006               2024-03-14
# 33   211.125748   28.167665   72.089820   95.694611               2025-02-27
# 34     9.209581   16.047904   44.862275   41.227545               2024-08-15
# 35     1.377246    0.359281    0.580838    0.431138               2024-08-22
# 36   103.209581    5.982036    0.784431    0.389222               2025-02-27
# 37   311.772455  185.718563  141.562874   84.005988               2025-02-13
# 38     1.059880    0.802395    0.497006    0.155689                      NaT
# 39   747.892216   37.119760   39.502994   33.658683               2025-03-06
# 40    84.251497  170.323353   17.730539    6.401198               2024-12-05
# 41  1041.886228   45.538922  114.688623  125.610778               2024-10-31
# 42     1.323353    0.892216    0.317365    0.197605               2024-03-20
# 43     1.083832    1.251497    1.125749    0.341317               2021-12-03
# 44     0.203593    0.257485    0.419162    0.532934               2024-09-12
# 45     9.425150    1.676647    3.347305    4.616766                      NaT
# 46   303.556886   71.790419    1.508982    1.485030               2025-02-13
# 47   108.275449   36.107784   23.131737   10.724551               2024-12-12
# 48   188.844311   25.257485   37.473054   15.910180               2025-01-28
# 49   348.868264  132.000000   91.497006   40.550898               2025-01-28

# %%
df
# Out:
#                                    Name           City State      Level A  \
# 0               ADAMS COUNTY DET CENTER        NATCHEZ    MS  1876.461078
# 1        ADELANTO ICE PROCESSING CENTER       ADELANTO    CA     6.401198
# 2    ALAMANCE COUNTY DETENTION FACILITY         GRAHAM    NC     4.329341
# 3           ALEXANDRIA STAGING FACILITY     ALEXANDRIA    LA   137.520958
# 4                  ALLEGANY COUNTY JAIL        BELMONT    NY     1.221557
# ..                                  ...            ...   ...          ...
# 129  WASHINGTON COUNTY DETENTION CENTER   FAYETTEVILLE    AR     0.922156
# 130                  WASHOE COUNTY JAIL           RENO    NV     0.814371
# 131        WEBB COUNTY DETENTION CENTER         LAREDO    TX   234.455090
# 132            WINN CORRECTIONAL CENTER      WINNFIELD    LA  1013.023952
# 133              WYATT DETENTION CENTER  CENTRAL FALLS    RI    16.221557
#
#         Level B     Level C    Level D Last Inspection End Date
# 0    266.431138    6.724551   4.257485               2025-01-16
# 1      4.323353   22.604790  32.634731               2024-07-18
# 2      3.461078    6.083832   6.185629               2024-09-19
# 3     47.413174   76.005988  52.485030               2024-08-29
# 4      0.018000    0.000000   0.000000                      NaT
# ..          ...         ...        ...                      ...
# 129    1.119760    1.203593   0.401198               2023-11-02
# 130    2.023952    3.443114   3.700599               2024-11-07
# 131    4.335329   27.724551  52.934132               2025-02-06
# 132  214.772455  187.005988  94.580838               2025-01-16
# 133    4.077844   42.329341  49.197605               2024-09-19
#
# [134 rows x 8 columns]

# %% [markdown]
# ##  Replace Empty and Whitespace Values to Missing (NaN)
#
# Some cells  contain only spaces or whitespace characters.
#
# This step replaces:
# - Empty strings (`""`)
# - Strings with only spaces (`"   "`)
#
# with proper missing values (`NaN`).
#
# This is important because pandas does not treat whitespace as missing by default,
# and keeping them can cause errors during analysis and cleaning.

# %%
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
missing_cells = df.isna()
print(df[missing_cells.any(axis=1)])
# Out:
#                                           Name            City State  \
# 4                         ALLEGANY COUNTY JAIL         BELMONT    NY
# 6                                 ATLANTAUSPEN         ATLANTA   NaN
# 8                         BERLIN FED CORR INST          BERLIN    NH
# 11                         BROWARD COUNTY JAIL   FT.LAUDERDALE    FL
# 22                     CIMMARRON CORR FACILITY         CUSHING    OK
# 38                   EL PASO SOFT SIDED FACILI         EL PASO    TX
# 45                            FDC PHILADELPHIA    PHILADELPHIA    PA
# 51                          GEAUGA COUNTY JAIL             NaN    OH
# 55                          GREENE COUNTY JAIL     SPRINGFIELD    MO
# 58           HONOLULU FEDERAL DETENTION CENTER        HONOLULU    HI
# 71   LA SALLE COUNTY REGIONAL DETENTION CENTER         ENCINAL   NaN
# 73                 LEAVENWORTH US PENITENTIARY     LEAVENWORTH    KS
# 79                     MIAMI FEDERAL DETENTION           MIAMI    FL
# 80                      MIAMI STAGING FACILITY           MIAMI    FL
# 84           NASSAU COUNTY CORRECTIONAL CENTER     EAST MEADOW    NY
# 87          NORTHEAST OHIO CORRECTIONAL CENTER      YOUNGSTOWN    OH
# 113                           SAN JUAN STAGING        GUAYNABO    PR
# 116                                        NaN       ELK RIVER    MN
# 121           STE GENEVIEVE COUNTY SHERIFFJAIL  STE. GENEVIEVE    MO
# 123                                        NaN           DOVER    NH
# 128                  TWO BRIDGES REGIONAL JAIL       WISCASSET    ME
#
#        Level A    Level B    Level C    Level D Last Inspection End Date
# 4     1.221557   0.018000   0.000000   0.000000                      NaT
# 6    17.341317   3.610778   3.053892   2.724551                      NaT
# 8     1.748503   0.089800   0.970060   0.712575                      NaT
# 11    0.335329   0.209581   1.053892   0.233533                      NaT
# 22   17.059880   3.670659   0.311377   0.000000                      NaT
# 38    1.059880   0.802395   0.497006   0.155689                      NaT
# 45    9.425150   1.676647   3.347305   4.616766                      NaT
# 51   24.676647  13.059880   7.580838   2.694611               2025-01-30
# 55   14.502994   3.083832   8.598802   5.886228                      NaT
# 58    3.814371   6.970060  10.586826   3.988024                      NaT
# 71    8.910180   0.706587   0.000000   0.071900               2025-02-07
# 73    5.652695   1.461078   3.574850   4.359281                      NaT
# 79   10.497006   8.371257  38.491018  21.053892                      NaT
# 80    1.604790   0.742515   0.544910   0.281437                      NaT
# 84    1.712575   0.317365   0.389222   0.383234                      NaT
# 87    8.658683   4.000000   3.245509   3.059880                      NaT
# 113   4.281437   0.251497   0.592814   0.179641                      NaT
# 116   4.592814   5.598802   9.281437   2.760479               2024-05-02
# 121   0.071900   1.113772   0.742515   0.215569                      NaT
# 123   0.000000   0.000000  49.161677  41.335329               2024-09-12
# 128   0.000000   0.000000   1.095808   0.844311                      NaT

# %% [markdown]
# ## Manual Data Corrections
#
# The following values were manually corrected after verifying facility information using
# Google Maps and official ICE detention facility records:
# for eg:
# - Missing city value for a facility located in Ohio
# - Missing facility names for facilities located in Minnesota (MN) and New Hampshire (NH)
#
# All other cleaning steps were performed programmatically.

# %%
df.loc[(df['City'].isna()) & (df['State'] == 'OH'), 'City'] = 'CHARDON'
df.loc[(df['Name'].isna()) & (df['State'] == 'MN'), 'Name'] = 'SHERBURNE COUNTY JAIL'
df.loc[(df['Name'].isna()) & (df['State'] == 'NH'), 'Name'] = 'STRAFFORD COUNTY CORRECTIONS'
df.loc[(df['State'].isna()) & (df['City'] == 'ATLANTA'), 'State'] = 'ATL'
df.loc[(df['State'].isna()) & (df['City'] == 'ENCINAL'), 'State'] = 'TX'
df.iloc[0, 0] = 'ADAMS COUNTY DETECTION CENTER'

# %% [markdown]
# # Checking After Filling with the Correct Name

# %%
print(df[df.isna().any(axis=1)])
# Out:
#                                    Name            City State    Level A  \
# 4                  ALLEGANY COUNTY JAIL         BELMONT    NY   1.221557
# 6                          ATLANTAUSPEN         ATLANTA   ATL  17.341317
# 8                  BERLIN FED CORR INST          BERLIN    NH   1.748503
# 11                  BROWARD COUNTY JAIL   FT.LAUDERDALE    FL   0.335329
# 22              CIMMARRON CORR FACILITY         CUSHING    OK  17.059880
# 38            EL PASO SOFT SIDED FACILI         EL PASO    TX   1.059880
# 45                     FDC PHILADELPHIA    PHILADELPHIA    PA   9.425150
# 55                   GREENE COUNTY JAIL     SPRINGFIELD    MO  14.502994
# 58    HONOLULU FEDERAL DETENTION CENTER        HONOLULU    HI   3.814371
# 73          LEAVENWORTH US PENITENTIARY     LEAVENWORTH    KS   5.652695
# 79              MIAMI FEDERAL DETENTION           MIAMI    FL  10.497006
# 80               MIAMI STAGING FACILITY           MIAMI    FL   1.604790
# 84    NASSAU COUNTY CORRECTIONAL CENTER     EAST MEADOW    NY   1.712575
# 87   NORTHEAST OHIO CORRECTIONAL CENTER      YOUNGSTOWN    OH   8.658683
# 113                    SAN JUAN STAGING        GUAYNABO    PR   4.281437
# 121    STE GENEVIEVE COUNTY SHERIFFJAIL  STE. GENEVIEVE    MO   0.071900
# 128           TWO BRIDGES REGIONAL JAIL       WISCASSET    ME   0.000000
#
#       Level B    Level C    Level D Last Inspection End Date
# 4    0.018000   0.000000   0.000000                      NaT
# 6    3.610778   3.053892   2.724551                      NaT
# 8    0.089800   0.970060   0.712575                      NaT
# 11   0.209581   1.053892   0.233533                      NaT
# 22   3.670659   0.311377   0.000000                      NaT
# 38   0.802395   0.497006   0.155689                      NaT
# 45   1.676647   3.347305   4.616766                      NaT
# 55   3.083832   8.598802   5.886228                      NaT
# 58   6.970060  10.586826   3.988024                      NaT
# 73   1.461078   3.574850   4.359281                      NaT
# 79   8.371257  38.491018  21.053892                      NaT
# 80   0.742515   0.544910   0.281437                      NaT
# 84   0.317365   0.389222   0.383234                      NaT
# 87   4.000000   3.245509   3.059880                      NaT
# 113  0.251497   0.592814   0.179641                      NaT
# 121  1.113772   0.742515   0.215569                      NaT
# 128  0.000000   1.095808   0.844311                      NaT

# %% [markdown]
# ## Checking row-wise if all values are NaN

# %%
fully_empty_rows = df[df.isna().all(axis=1)]
print(fully_empty_rows)
# Out:
# Empty DataFrame
# Columns: [Name, City, State, Level A, Level B, Level C, Level D, Last Inspection End Date]
# Index: []

# %% [markdown]
# ## Checking if the duplicate value is present

# %%
duplicates_all = df[df.duplicated()]
print(duplicates_all)
# Out:
# Empty DataFrame
# Columns: [Name, City, State, Level A, Level B, Level C, Level D, Last Inspection End Date]
# Index: []

# %% [markdown]
# ## Exporting the Final cleaned data

# %%
df.to_csv("data/cleaned_ice_detention.csv",index=False,encoding="utf-8")

# %% [markdown]
# # 2.Data Analyzing

# %% [markdown]
# ## Reimport Required Libraries
#
# We import the main library used for data cleaning:
#
# - **pandas (pd)** → Used for reading, writing, and cleaning tabular data like CSV files.
#
# These library is essential for any data analysis or data cleaning task in Python.

# %%
import pandas as pd

# %% [markdown]
# ## Creating Total Population Column
#
# To determine the largest detention facilities, a new column called **Total Population** was created by summing the four custody-level columns: **Level A**, **Level B**, **Level C**, and **Level D**.
#
#
#
# ### Formula
#
# Total Population = Level A + Level B + Level C + Level D

# %%
df = pd.read_csv("data/cleaned_ice_detention.csv")
df["Total Population"] = (df["Level A"]+ df["Level B"] + df["Level C"] + df["Level D"])

# %%
(df["Total Population"] == 0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Subsetting Top Ten Facilities .
#
#
#  The ten facilities with the highest total populations were selected for further analysis and visualization.

# %%
top10_largest_detention = df.nlargest(10,"Total Population")
print(top10_largest_detention)
# Out:
#                                         Name         City State      Level A  \
# 0              ADAMS COUNTY DETECTION CENTER      NATCHEZ    MS  1876.461078
# 119        SOUTH TEXAS ICE PROCESSING CENTER     PEARSALL    TX  1299.083832
# 122                 STEWART DETENTION CENTER      LUMPKIN    GA   743.311377
# 132                 WINN CORRECTIONAL CENTER    WINNFIELD    LA  1013.023952
# 93                OTAY MESA DETENTION CENTER    SAN DIEGO    CA   800.826347
# 41            ELOY FEDERAL CONTRACT FACILITY         ELOY    AZ  1041.886228
# 83        MOSHANNON VALLEY PROCESSING CENTER  PHILIPSBURG    PA   205.245509
# 82          MONTGOMERY ICE PROCESSING CENTER       CONROE    TX   149.556886
# 18   CENTRAL LOUISIANA ICE PROCESSING CENTER         JENA    LA   410.970060
# 31        DENVER CONTRACT DETENTION FACILITY       AURORA    CO   624.568862
#
#         Level B     Level C     Level D Last Inspection End Date  \
# 0    266.431138    6.724551    4.257485               2025-01-16
# 119  106.125749  188.724551   68.197605               2025-02-06
# 122  194.928144  371.562874  328.041916               2024-08-01
# 132  214.772455  187.005988   94.580838               2025-01-16
# 93   470.119760   45.479042   46.215569               2024-11-07
# 41    45.538922  114.688623  125.610778               2024-10-31
# 83    96.467066  542.275449  402.059880               2025-03-06
# 82   561.425150  355.269461  160.976048               2024-12-05
# 18   221.209581  344.790419  207.161677               2025-01-09
# 31   190.508982  189.658683  141.365270               2025-02-13
#
#      Total Population
# 0         2153.874252
# 119       1662.131736
# 122       1637.844311
# 132       1509.383233
# 93        1362.640719
# 41        1327.724551
# 83        1246.047904
# 82        1227.227545
# 18        1184.131736
# 31        1146.101796

# %% [markdown]
# # Exporting the csv of the top 10 detention centre

# %%
top10_largest_detention.to_csv("data/top_10_detention_facilities.csv",index=False)

# %% [markdown]
# # 3. visualizing top 10 detention centre on the basis of the population

# %% [markdown]
# # Reimport Required Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the top 10 largest detention  facilities for the Visualization

# %%
top_10_largest_detention = pd.read_csv("data/top_10_detention_facilities.csv")
top_10_largest_detention
# Out:
#                                       Name         City State      Level A  \
# 0            ADAMS COUNTY DETECTION CENTER      NATCHEZ    MS  1876.461078
# 1        SOUTH TEXAS ICE PROCESSING CENTER     PEARSALL    TX  1299.083832
# 2                 STEWART DETENTION CENTER      LUMPKIN    GA   743.311377
# 3                 WINN CORRECTIONAL CENTER    WINNFIELD    LA  1013.023952
# 4               OTAY MESA DETENTION CENTER    SAN DIEGO    CA   800.826347
# 5           ELOY FEDERAL CONTRACT FACILITY         ELOY    AZ  1041.886228
# 6       MOSHANNON VALLEY PROCESSING CENTER  PHILIPSBURG    PA   205.245509
# 7         MONTGOMERY ICE PROCESSING CENTER       CONROE    TX   149.556886
# 8  CENTRAL LOUISIANA ICE PROCESSING CENTER         JENA    LA   410.970060
# 9       DENVER CONTRACT DETENTION FACILITY       AURORA    CO   624.568862
#
#       Level B     Level C     Level D Last Inspection End Date  \
# 0  266.431138    6.724551    4.257485               2025-01-16
# 1  106.125749  188.724551   68.197605               2025-02-06
# 2  194.928144  371.562874  328.041916               2024-08-01
# 3  214.772455  187.005988   94.580838               2025-01-16
# 4  470.119760   45.479042   46.215569               2024-11-07
# 5   45.538922  114.688623  125.610778               2024-10-31
# 6   96.467066  542.275449  402.059880               2025-03-06
# 7  561.425150  355.269461  160.976048               2024-12-05
# 8  221.209581  344.790419  207.161677               2025-01-09
# 9  190.508982  189.658683  141.365270               2025-02-13
#
#    Total Population
# 0       2153.874252
# 1       1662.131736
# 2       1637.844311
# 3       1509.383233
# 4       1362.640719
# 5       1327.724551
# 6       1246.047904
# 7       1227.227545
# 8       1184.131736
# 9       1146.101796

# %% [markdown]
# # Visualizing the top detention centre

# %%
# -----------------------------
# Visualization (Bar Chart)
# -----------------------------

plt.figure(figsize=(18, 12))

bars = plt.barh(
    top_10_largest_detention["Name"],
    top_10_largest_detention["Total Population"],
    height=0.6,
    color="#9e0000",
    edgecolor="black",
    linewidth=0.5
)

#keeping the largest one at the top
plt.gca().invert_yaxis()


plt.xlabel("Total Population",fontsize=18,labelpad=20,fontweight="bold")
plt.ylabel("Detention Facility",fontsize=18,fontweight="bold")
plt.title("Top 10 Detention Facilities by Total Population",fontsize=22,fontweight="bold",pad=15,loc="center")


#add the tick label size
plt.gca().tick_params(axis='y', labelsize=16)
plt.gca().tick_params(axis='x', labelsize=16)


max_val = top_10_largest_detention["Total Population"].max()


# Add value labels
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + max(top_10_largest_detention["Total Population"]) * 0.01,
        bar.get_y() + bar.get_height() / 2,
        f"{int(width):,}",
        va="center",
        ha="left",
        fontsize=14
    )
#Add subtle gridlines

plt.grid(axis="x", linestyle="--", alpha=0.3)



# Adjust plot spines for neatline
ax = plt.gca()
ax.spines['top'].set_visible(False)      # remove top line
ax.spines['right'].set_visible(False)    # remove right line
ax.spines['left'].set_linewidth(1.5)     # left spine
ax.spines['bottom'].set_linewidth(1.5) 

#manual adjustmenr for nice spacing
plt.subplots_adjust(
    left=0.32,   # more space for long facility names
    right=0.95,
    top=0.90,
    bottom=0.10
)

plt.figtext(
    0.5, 0.06,
    "Source: ICE Integrated Decision Support (IIDS), 03/17/2025.\n "
    "Includes facilities with population ≥ 1; excludes HOLD, HOSPITAL, HOTEL, ORR, and MIRP facilities. "
    "Publicly released under DHS Appropriations Act, 2020 (H.R. 1158, Sec. 218). Data subject to change.",
    ha="center",
    fontsize=11,
    wrap=True,
    linespacing=1.5
),

plt.subplots_adjust(bottom=0.18)
plt.savefig("data/top_10_detention_facilities.png", dpi=900,)
plt.show()
